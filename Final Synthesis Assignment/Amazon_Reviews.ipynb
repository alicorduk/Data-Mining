# %% [markdown]
# # Synthesis Assignment (100)

# %% [markdown]
# ## Group Information
#
# Use the form fields below to input your group number and group member information.

# %%
# @title Group Number { run: "auto" }
groups = list(range(1,23))
Group_Number = 2 # @param [groups] {type:"integer"}
print('Group Number:', Group_Number)
# Out:
# Group Number: 2

# %%
# @title Group Member Full Names { run: "auto" }
Group_Member_1 = 'Arefa Attar' # @param {type:"string", placeholder:"Enter Full Name 1"}
Group_Member_2 = 'Muhammed Corduk' # @param {type:"string", placeholder:"Enter Full Name 2"}
Group_Member_3 = 'Abdullah Khan Pathan' # @param {type:"string", placeholder:"Enter Full Name 3"}
Group_Member_4 = 'Nishitha Reddy Vedire' # @param {type:"string", placeholder:"Enter Full Name 4"}
Group_Member_5 = ''
print('Group Members:')
print(Group_Member_1)
print(Group_Member_2)
print(Group_Member_3)
print(Group_Member_4)
print(Group_Member_5)
# Out:
# Group Members:
# Arefa Attar
# Muhammed Corduk
# Abdullah Khan Pathan
# Nishitha Reddy Vedire

# %% [markdown]
# ---

# %% [markdown]
# ## Directions
# In the Synthesis Assignment, which will be submitted in two parts, your group will perform text analytics to solve a real-world business problem. As a group, you will choose one of the following 5 business problems and accompanying dataset.
#
# <br>
#
# | Business Problem (Prediction)| Topic | Data Type | Dataset Name |
# | ----------- | ----------- | ----------- | ----------- |
# | Rating or Sentiment|Lotion|Online reviews|lotion-reviews.csv|
# | Spam Detection|         |E-mails|spam.csv|
# | Rating or Recommendation | Airlines| Customer surveys| airlines.csv|
# | Rating| Weight Loss Drugs|Customer surveys| weightloss.csv|
# | Rating| Amazon Products| Online reviews|amazon_reviews.csv|
#
# <br>
#
# First, type your group number and group member names in the text cells above.
#
# Rename this template file - <b>INFO585_SA_Group#.ipynb</b>, where # is the assignment number. As an example, Group 1's Synthesis Assignment submission would be named **INFO585_SA_Group1.ipynb**. Note: Your .pdf submission file naming will also follow this format.
#
# <br>
#
# **Submission:**
#
# Your submission (one per group) for each assignment part will include:
# *  (1) .ipynb file (with code run), following the naming instructions above
# * (1) .pdf of the .ipynb file (with all code run). Can be obtained using File -> Print.
#
#
# <br>
#
# **Overview:**
#
# <br>
#
# **Part 1**
#
# **Due:** 12/1 at 11:59 PM ET
#
# In Part 1, you will define the business problem, cleanse and preprocess the data, and perform exploratory data analysis. To complete Part 1, you will fill in the required information in the [Part 1](#scrollTo=cwyEfhMwUTT1) Section.
#
# <br>
#
# **Part 2**
#
# **Due:** 12/15 at 11:59 PM ET
#
# In Part 2, you will perform predictive analysis, evaluate your predictive models, and make recommendations and discuss your results within the context of the business problem. To complete Part 2, you will fill include all required information for Part 1 and fill in the required information in the [Part 2](#scrollTo=8fZ_eKishBVo) Section.

# %% [markdown]
# <hr>
# <br>

# %% [markdown]
# # **Part 1 (50)**

# %% [markdown]
# ## Directions
#
# Include your code and any required written information immediately under the relevant sections or prompts in the space provided.
#
# You will include all prerequisite code (load packages, etc.) necessary for your code in Part 1  to run in the [Prerequisite Code](#scrollTo=1NApcFUYjX8g) Section below.
#
# You will submit your code and written responses in this .ipynb template notebook in the space provided under the sectioned prompts. Under the prompts there are code and/or text cells provided. If additional cells are needed, add the cells under the appropriate heading.
#
# Your code and written responses should be easy for someone who did not write the code or perform the analysis to follow. Points will be deducted for extraneous code or if file naming instructions are not followed.
#
# **Note:** Your Part 1 submission will only include responses for Part 1. Part 2 should remain hidden in the Part 1 submission.
#
# <br>
#
# **Submission:**
#
# **Due:** 12/1 at 11:59 PM ET
#
# **Points:** 50
#
# Your submission (one per group) for Part 1 will include:
# *  (1) .ipynb file (with code run), following the naming instructions above
# * (1) .pdf of the .ipynb file (with code run). Can be obtained using File -> Print.
#
# **Note:** Your Part 1 submission will only include responses for Part 1. Please hide Part 2 if it contains any code or responses prior to submitting.

# %% [markdown]
# ## 1.0 Prerequisite Code

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from bs4 import BeautifulSoup
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ## 1.1 Problem Definition & Statement (20)

# %% [markdown]
# **1.1 A (5) First, use the code cell below to identify your group's selected dataset and the target variable (column name) that will be used for predictive modeling.**

# %%
# @title Identify Problem/Dataset

Dataset = 'amazon_reviews.csv' # @param ["lotion-reviews.csv", "spam.csv", "airlines.csv", "weightloss.csv", "amazon_reviews.csv"]
Target_Variable = 'overall ' # @param {type:"string"}

print(Dataset)
print(Target_Variable)

# %% [markdown]
# **1.1 B (15) Next, use the text cell below for your problem definition and statement.**
#
# **The problem statement should discuss the following: what is the problem and who it affects, financial/social implications of having a solution to the problem, how the model would be used in practice, and the acceptable level of model performance.**

# %% [markdown]
# # **Business Problem**
#
# A major determinant of the reputation and success of goods offered for sale on websites is customer feedback. Companies like Amazon faces a significant challenge in accurately and efficiently identifying and understanding the negative sentiments expressed in a large volume of customer reviews. The unstructured, typo-ridden, and stylistically diverse text makes it difficult to distinguish between product-specific issues (e.g., defects, usability problems) and broader service-related complaints (e.g., delivery delays). This lack of clarity not only impedes Amazon’s ability to address underlying problems but also results in diminished customer trust, damage to brand reputation, and financial losses due to refunds, replacements, and missed sales opportunities.
#
# **Affected Parties:**
#
# Consumers struggle to find specific information, such as product qualities, benefits, or drawbacks, amid the large number of ratings for popular products. This issue affects various parties. Companies might lose chances to improve their goods or quickly address consumer concerns, which might cost them money and harm the credibility of their brand. Although depending on high-quality, insightful feedback, Amazon and other marketplaces face challenges when disorganised or unmoderated reviews undermine user trust and interfere with the consumer experience.
#
# **Social/Financial Implications:**
#
# Overcoming this barrier has several benefits: businesses may use insightful data from structured feedback to improve customer satisfaction, increase product quality, and eventually boost sales. Concurrently, consumers can benefit from clear, and relevant evaluations that increase their faith in the platform and assist them in making informed purchasing decisions.
#
# **Model Uses:**
#
# Businesses can organise feedback from consumers into appropriate categories by using data-driven methods like sentiment analysis and clustering models. These techniques help businesses identify common product issues, identify high-performing characteristics, and monitor trends in customer satisfaction. Businesses can utilise these advanced tools to transform fragmented input into insightful information that improves decision-making and resource allocation. By paying attention to client demands, these strategies improve product offers and foster enduring relationships with customers. Ultimately, resolving this issue fosters a more efficient, transparent, and customer-focused surroundings, which enhances the online purchasing experience for both consumers and businesses.

# %% [markdown]
# <hr>
# <br>
#
# ## 1.2 Data: Cleansing and Preprocessing (15)

# %% [markdown]
# **1.2 A (10) Use the code cell below (and add any additional cells, as necessary, below the provided cell) to cleanse and preprocess the data that you will use in your analysis.**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
reviews = pd.read_csv('/content/drive/MyDrive/amazon_reviews.csv')

# %%
reviews.head()
# Out:
#          asin      reviewerID  \
# 0  B00002243X  A1R089P5AS26UE
# 1  B00008RW9U  A24EQC4LXYPT4E
# 2  B00008RW9U  A32TGXG3ZWJ4DY
# 3  B00008RW9U  A2RO3DC31WU3LY
# 4  B00008RW9U  A1QF996642YT9L
#
#                                           reviewText  overall  \
# 0  I have an old car, Its bound to need these som...        5
# 1  Takes the dust off my car without leaving any ...        5
# 2  This thing is great. I had another one from a ...        5
# 3  As we all know, dust gets over your rides in t...        5
# 4  Maybe I don't understand the finer points of k...        3
#
#                                              summary  unixReviewTime  \
# 0                                              Beefy      1390348800
# 1                                        What to say      1400198400
# 2                                           The Best      1399248000
# 3                                  california duster      1401148800
# ...

# %%
reviews.info()
sns.heatmap(reviews.isnull(), cbar=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5743 entries, 0 to 5742
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   asin            5743 non-null   object
#  1   reviewerID      5743 non-null   object
#  2   reviewText      5743 non-null   object
#  3   overall         5743 non-null   int64
#  4   summary         5743 non-null   object
#  5   unixReviewTime  5743 non-null   int64
#  6   helpful_votes   5743 non-null   int64
#  7   total_votes     5743 non-null   int64
#  8   product_brand   4157 non-null   object
#  9   product_title   4964 non-null   object
#  10  product_price   5677 non-null   float64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 493.7+ KB
# <Axes: >

# %%
reviews = reviews.dropna(subset=['product_brand', 'product_title', 'product_price'])

# %%
reviews.drop(['asin','reviewerID','unixReviewTime', 'summary', 'helpful_votes', 'product_title'], axis=1, inplace=True)

# %% [markdown]
# **1.2 B (5) In the text cell below, briefly describe and discuss (in paragraph format) the cleansing and preprocessing steps taken to prepare the data for analysis.**

# %% [markdown]
# Identifying and correcting missing information was the main focus of the initial data cleaning steps, particularly in the product_brand column where there were many null entries. Rows without product_brand values were removed to ensure analytical consistency. To further simplify the dataset and retain only the key features (reviewText, overall rating, total_votes, and product_brand) for the analysis, unnecessary columns such as asin, reviewerID, unixReviewTime, summary, helpful_votes, product_title, and product_price were eliminated.
#
# To preserve clarity during the preparation phases, the lack of data was shown via a heatmap. Making decisions regarding data cleansing was aided by this visualisation, which made it easier to understand the extent and distribution of missing data. The dataset was prepared for analysis by focussing on relevant columns and removing incomplete entries, making sure it was consistent, well-structured, and suitable for the impending modelling and exploratory activities.

# %% [markdown]
# ---

# %% [markdown]
# ## 1.3 Data: Description & EDA (15)

# %% [markdown]
# **1.3 A (8) Use the code cell below (and add any additional cells, as necessary) to describe the data and perform exploratory data analysis.**
#
# **Description and EDA of the dataset should include: dataset overview, preview, dimensionality, visualization (text, target variable), descriptive statistics, and can include Cluster Analysis.**

# %%
reviews.head()
# Out:
#                                           reviewText  overall  total_votes  \
# 0  I have an old car, Its bound to need these som...        5            0
# 1  Takes the dust off my car without leaving any ...        5            0
# 2  This thing is great. I had another one from a ...        5            0
# 3  As we all know, dust gets over your rides in t...        5            0
# 4  Maybe I don't understand the finer points of k...        3            0
#
#            product_brand  product_price
# 0          Coleman Cable          55.99
# 1  California Car Duster          23.95
# 2  California Car Duster          23.95
# 3  California Car Duster          23.95
# 4  California Car Duster          23.95

# %%
print(f"Number of Rows: {reviews.shape[0]}")
print(f"Number of Columns: {reviews.shape[1]}")
# Out:
# Number of Rows: 4157
# Number of Columns: 5

# %%
print("\nDescriptive Statistics for Numerical Columns:")
print(reviews [['overall', 'product_price']].describe())
# Out:
# Descriptive Statistics for Numerical Columns:
#            overall  product_price
# count  4157.000000    4157.000000
# mean      4.519846      22.379021
# std       0.899098      35.334391
# min       1.000000       0.010000
# 25%       4.000000       7.990000
# 50%       5.000000      12.990000
# 75%       5.000000      23.280000
# max       5.000000     975.000000

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x=reviews['overall'], palette='viridis')
plt.title('Distribution of Overall Ratings')
plt.xlabel('Overall Ratings')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-11-1d3b88e0bc06>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=reviews['overall'], palette='viridis')

# %%
text_combined = ' '.join(reviews['reviewText'])
wc = WordCloud(min_font_size=16, max_words=250, background_color="white", width=800, height=400, random_state=123).generate(text_combined)

plt.figure(figsize=(8, 6))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
text_data = reviews['reviewText'].dropna()

tfidf_vectorizer = TfidfVectorizer(stop_words='english', max_features=1000)
tfidf_matrix = tfidf_vectorizer.fit_transform(text_data)

# Performing Elbow Analysis
Sum_of_squared_distances = []
cluster_range = range(2, 16)  # Clusters from 2 to 15

for k in cluster_range:
    kmeans = KMeans(n_clusters=k, random_state=123)
    kmeans.fit(tfidf_matrix)
    Sum_of_squared_distances.append(kmeans.inertia_)

plt.plot(cluster_range, Sum_of_squared_distances, 'bx-')
plt.xlabel('cluster_range')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
reviews['Sentiment'] = reviews['overall'].replace({1:0, 2:0, 3:0, 4:1, 5:1})

reviews.Sentiment.hist()

print('Positive label proportion: ', reviews.Sentiment.mean())
# Out:
# Positive label proportion:  0.8878999278325715

# %% [markdown]
# **1.3 B (7) In the text cell below, describe (in paragraph format) the dataset and any important findings from your description and EDA. A discussion of class imbalance should also be included if present.**

# %% [markdown]
# The Amazon dataset consists of customer reviews for various products and includes 10 columns. These columns provide details such as product ID, reviewer ID, review text, ratings, product brand, product price, and total votes. ReviewText, overall rating, total votes, and product brand data were used in this research since they were most pertinent for sentiment and clustering.
# Using exploratory data analysis, we discovered a number of significant findings. There is a clear difference in the overall ratings allocation because most reviews have a 5-star rating. ReviewText's word cloud shows often used terms like "car," "product," "use," and "work," which reflects the pragmatic nature of client input. Furthermore, an analysis of helpfulness votes shows that many evaluations have little to no interaction, indicating underutilised input, while the scree plot indicates that k = 5 is the ideal number for clustering jobs.

# %% [markdown]
# ---
#
# <br>

# %% [markdown]
# # **Part 2 (50)**

# %% [markdown]
# ## Directions
#
# Include your code and any required written information immediately under the relevant sections or prompts in the space provided.
#
# You will include all prerequisite code (load packages, etc.) necessary for your code in Part 2  to run in the [Prerequisite Code](#scrollTo=FJpS12HuCNnE) Section below.
#
# You will submit your code and written responses in this .ipynb template notebook in the space provided under the sectioned prompts. Under the prompts there are code and/or text cells provided. If additional cells are needed, add the cells under the appropriate heading.
#
# Your Synthesis Assignment Part 2 submission should include all Part 1 and Part 2 code and responses (with all code run).
#
# Your code and written responses should be easy for someone who did not write the code or perform the analysis to follow. Points will be deducted for extraneous code or if file naming instructions are not followed.
#
# <br>
#
#
# **Submission:**
#
# **Due:** 12/15 at 11:59 PM ET
#
# **Points:** 50
#
# Your submission (one per group) for Part 2 will include:
# *  (1) .ipynb file (with all code run), following the naming instructions above
# * (1) .pdf of the .ipynb file (with all code run). Can be obtained using File -> Print.

# %% [markdown]
# ## 2.0 Prerequisite Code

# %%
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer
# !pip install tensorflow==2.15.1
import tensorflow as tf
import spacy
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from keras.models import Sequential, load_model
from keras.layers import Dense, Flatten, LSTM, Conv1D, GlobalMaxPooling1D, Dropout, Activation, Input, TextVectorization, Embedding
from keras.callbacks import *
from keras.metrics import *
from keras.backend import clear_session
from keras.initializers import Constant
from keras.models import load_model
from sklearn.metrics import classification_report, recall_score, precision_score, f1_score, roc_curve, auc, precision_recall_curve
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 68.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 56.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 97.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 30.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.17.0
#     Uninstalling wrapt-1.17.0:
#       Successfully uninstalled wrapt-1.17.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: keras
#     Found existing installation: keras 3.5.0
#     Uninstalling keras-3.5.0:
#       Successfully uninstalled keras-3.5.0
# ...

# %% [markdown]
# ## 2.1 Analysis (25)

# %% [markdown]
# **2.1 (25) Perform (at least) 3 types of classification analysis demonstrated in the course. At least one type must be a deep learning model using either a pre-trained or data-trained embedding layer.**

# %%
X = reviews['reviewText']
y = reviews['Sentiment']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=123)

# %%
# Naive Bayes
nb_sent = Pipeline([
                    ('vect', CountVectorizer(stop_words = 'english')),
                    ('tfidf', TfidfTransformer()),
                    ('nb', MultinomialNB()),
                    ])

nb_sent.fit(X_train, y_train)

pred = nb_sent.predict(X_test)
pred_prob = nb_sent.predict_proba(X_test)[:, 1]

# Logistic regression
logistic_pipe = Pipeline([
    ('tfidf', TfidfVectorizer(stop_words='english', min_df=5)),
    ('logistic', LogisticRegression())
])

logistic_pipe.fit(X_train, y_train)
log_pred = logistic_pipe.predict(X_test)
log_pred_prob = logistic_pipe.predict_proba(X_test)[:, 1]
precision_log, recall_log, _ = precision_recall_curve(y_test, log_pred)

# LSTMs
tokenizer = Tokenizer()
tokenizer.fit_on_texts(list(X_train))

X_train_seq  = tokenizer.texts_to_sequences(X_train)
X_test_seq = tokenizer.texts_to_sequences(X_test)

X_train_seq  = pad_sequences(X_train_seq, maxlen=100)
X_test_seq = pad_sequences(X_test_seq, maxlen=100)

size_of_vocabulary=len(tokenizer.word_index) + 1
print(size_of_vocabulary)

METRICS = [
      TruePositives(name='tp'),
      FalsePositives(name='fp'),
      TrueNegatives(name='tn'),
      FalseNegatives(name='fn'),
      BinaryAccuracy(name='accuracy'),
      Precision(name='precision'),
      Recall(name='recall'),
      AUC(name='auc'),
      AUC(name='prc', curve='PR'), # precision-recall curve

]

clear_session()

model=Sequential()

model.add(Embedding(size_of_vocabulary,300,input_length=100,trainable=True))

model.add(LSTM(128,return_sequences=True,dropout=0.2))

model.add(GlobalMaxPooling1D())

model.add(Dense(64,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy',metrics=METRICS)

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=3)
mc=ModelCheckpoint('best_model', monitor='val_loss', mode='min', save_best_only=True, save_weights_only=False, verbose=1)

#Print summary of model
print(model.summary())
# Out:
# 9925
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 100, 300)          2977500
#
#  lstm (LSTM)                 (None, 100, 128)          219648
#
#  global_max_pooling1d (Glob  (None, 128)               0
#  alMaxPooling1D)
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 1)                 65
#
# ...
# Total params: 3205469 (12.23 MB)
# Trainable params: 3205469 (12.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# Fitting the LSTM model to the data
history = model.fit(np.array(X_train_seq),np.array(y_train),batch_size=128,epochs=10,
                    validation_data=(np.array(X_test_seq),np.array(y_test)),verbose=1,callbacks=[es,mc])
# Out:
# Epoch 1/10
# 23/23 [==============================] - ETA: 0s - loss: 0.4350 - tp: 2593.0000 - fp: 314.0000 - tn: 0.0000e+00 - fn: 2.0000 - accuracy: 0.8914 - precision: 0.8920 - recall: 0.9992 - auc: 0.4588 - prc: 0.8764
# Epoch 1: val_loss improved from inf to 0.37255, saving model to best_model
# 23/23 [==============================] - 58s 2s/step - loss: 0.4350 - tp: 2593.0000 - fp: 314.0000 - tn: 0.0000e+00 - fn: 2.0000 - accuracy: 0.8914 - precision: 0.8920 - recall: 0.9992 - auc: 0.4588 - prc: 0.8764 - val_loss: 0.3726 - val_tp: 1096.0000 - val_fp: 152.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.8782 - val_precision: 0.8782 - val_recall: 1.0000 - val_auc: 0.5537 - val_prc: 0.8913
# Epoch 2/10
# 23/23 [==============================] - ETA: 0s - loss: 0.3428 - tp: 2595.0000 - fp: 314.0000 - tn: 0.0000e+00 - fn: 0.0000e+00 - accuracy: 0.8921 - precision: 0.8921 - recall: 1.0000 - auc: 0.5153 - prc: 0.8968
# ...

# %% [markdown]
# ## 2.2 Model Evaluation (15)

# %% [markdown]
# **2.2 A (8) Evaluate the models on both the training and testing sets to obtain both performance and goodness of fit.**

# %%
# Naive Bayes Results
print("\nNaive Bayes\n")
print(classification_report(y_test, pred))

fpr, tpr, thresholds = roc_curve(y_test, pred_prob)
precision, recall, thresholds_pr = precision_recall_curve(y_test, pred)

print('ROC AUC: ', auc(fpr, tpr))
print('Precision/Recall AUC: ', auc(precision, recall))
# Out:
# Naive Bayes
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       152
#            1       0.88      1.00      0.94      1096
#
#     accuracy                           0.88      1248
#    macro avg       0.44      0.50      0.47      1248
# weighted avg       0.77      0.88      0.82      1248
#
# ROC AUC:  0.6403248655397619
# Precision/Recall AUC:  0.0608974358974359
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# Logistic regression results
print("\nLogistic Regression\n")
print(classification_report(y_test, log_pred))
fpr_log, tpr_log, _ = roc_curve(y_test, log_pred_prob)
print('ROC AUC: ', auc(fpr_log, tpr_log))
print('Precision/Recall AUC: ', auc(recall_log, precision_log))
# Out:
# Logistic Regression
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.01      0.01       152
#            1       0.88      1.00      0.94      1096
#
#     accuracy                           0.88      1248
#    macro avg       0.94      0.50      0.47      1248
# weighted avg       0.89      0.88      0.82      1248
#
# ROC AUC:  0.7965448520937382
# Precision/Recall AUC:  0.9394546912590216

# %%
# LSTMs Results
print("\nLSTM\n")
model_results = model.evaluate(X_test_seq, y_test, batch_size=128, verbose=0)

for name, value in zip(model.metrics_names, model_results):
  print(name, ': ', value)
# Out:
# LSTM
#
# loss :  0.5709881782531738
# tp :  1069.0
# fp :  123.0
# tn :  29.0
# fn :  27.0
# accuracy :  0.879807710647583
# precision :  0.8968120813369751
# recall :  0.9753649830818176
# auc :  0.6926442980766296
# prc :  0.9247947335243225

# %% [markdown]
# **2.2 B (7) Based on your output in 2.2A, discuss and compare the goodness of fit and performance for each of the classification models. Which model is preferred? Why? Explain.**

# %% [markdown]
# Focusing on Precision/Recall (PR) AUC, the **Logistic Regression** model clearly stands out. With a PR AUC of approximately 0.9395, it outperforms both the Naive Bayes model (around 0.06) and the LSTM model (around 0.92). A high PR AUC means that, overall, Logistic Regression does a better job ranking negative reviews higher than positive ones. In other words, if we sort reviews by their likelihood of being negative according to each model, Logistic Regression would provide a more accurate ordering, placing actual negative reviews nearer the top on average.
#
# While Logistic Regression excels in terms of PR AUC, it struggled with actual recall at a chosen threshold for the minority class (negative reviews). This means that, although it’s very good at ranking negative instances ahead of positive ones, it doesn’t necessarily catch enough of them when a specific cutoff is applied. Conversely, the LSTM model, while having a slightly lower PR AUC, identified more negative reviews in practice. So, while PR AUC highlights the strong ranking ability of Logistic Regression, other metrics show that a model’s effectiveness also depends on how well it performs when making hard classification decisions.

# %% [markdown]
# ## 2.3 Discussion & Conclusion (10)

# %% [markdown]
# **2.3 (10) Briefly summarize the problem statement and data. Then, discuss your analysis and findings. Within the context of the business problem and your analysis results, provide business recommendations. Be sure to discuss any limitations, constraints, or ethical concerns that could impact the implementation of the recommended solution.**

# %% [markdown]
# Effectively detecting and comprehending negative sentiments in its enormous number of customer evaluations is Amazon's biggest issue. These evaluations, which are frequently unstructured and feature typos or a variety of writing styles, make it challenging to distinguish between complaints about services (like delivery delays) and product-specific issues (like flaws or usability issues). Strong analytical models are required to categorise feelings and offer useful insights because the data contains a combination of structured information, such as ratings, and unstructured text from reviews. Negative reviews can damage a brand's reputation, client trust, and financial results if ignored.
#
# ### **Analysis and Findings**
#
# We used three models — Naive Bayes, Logistic Regression, and LSTM — to classify customer reviews as positive or negative. Logistic Regression achieved the highest Precision/Recall (PR) AUC of approximately 0.9395, indicating its strength in ranking negative reviews ahead of positive ones. However, its low recall for negative reviews limits its ability to identify them effectively at a specific decision threshold. In contrast, the LSTM model, with a slightly lower PR AUC (~0.92), performed better at identifying negative reviews in practice. Naive Bayes struggled significantly, failing to identify any negative reviews effectively.
#
# ###**Recommendations**
# To tackle the challenge of identifying negative reviews, a practical solution is to combine the strengths of both Logistic Regression and LSTM models. Logistic Regression excels at ranking reviews, making it great for prioritizing which ones to address first, while LSTM’s better recall ensures more negative reviews are accurately identified. To make the system even better, techniques like fine-tuning thresholds, rebalancing the classes, or using ensemble methods can help overcome the limitations of Logistic Regression and improve its ability to catch negative reviews. Automating the categorization of feedback into actionable insights—such as pinpointing common product issues or service complaints—can make it easier to address specific concerns and improve customer satisfaction. Finally, to keep the system effective, it’s important to regularly review and update the models, retraining them with new data to ensure they stay in tune with evolving customer needs.
#
# ###**Limitations**
#
# The imbalance between positive and negative reviews creates a real challenge for model performance. Models like LSTM, even though they’re powerful, aren’t as easy to understand as simpler models like Logistic Regression. This lack of transparency can be a hurdle for stakeholders who need clear explanations of how decisions are made. Ethical concerns also play a big role here—automated systems need to be careful not to reinforce biases, like unfairly flagging reviews from certain groups or products. It’s crucial to ensure data processing is done transparently and fairly to avoid ethical pitfalls. Finally, advanced models like LSTM can be expensive and resource-heavy to implement and maintain, so businesses need to carefully weigh the costs and infrastructure demands before committing to them.
